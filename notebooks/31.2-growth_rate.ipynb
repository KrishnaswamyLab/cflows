# %%
import numpy as np
import scanpy as sc
import scprep
import matplotlib.pyplot as plt
import phate
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
adata_all = sc.read('../data/rna_figure_ready.h5ad')
# subsampled_df = pd.read_csv('../data/mioflow_balanced_subsampled.csv', index_col=0)
# adata = adata_all[subsampled_df.index]
adata = adata_all
# Out:
# /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/.conda_envs/mioflow/lib/python3.10/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
# scaler = StandardScaler()
# adata.obsm['X_phate'] = scaler.fit_transform(adata.obsm['X_phate'])

# %%
sc.external.pl.phate(adata, color='growth', cmap='inferno', vmax=2)

# %%
sc.external.pl.phate(adata[adata.obs['day'] == 0.0], color='growth', vmax=2)

# %%
adata[adata.obs['day'] == 0.0].obs['growth'].hist(bins=100)
# Out:
# <Axes: >

# %%
scprep.plot.scatter2d(adata[adata.obs['day'] == 0.0].obsm['X_phate'], adata[adata.obs['day'] == 0.0].obs['growth'] < 1.0, alpha=.5)
scprep.plot.scatter2d(adata[adata.obs['day'] == 0.0][adata[adata.obs['day'] == 0.0].obs['growth'] < 1.0].obsm['X_phate'])
# Out:
# <Axes: >

# %%
adata.obs['growth'].to_csv('../data/growth_rate.csv')
