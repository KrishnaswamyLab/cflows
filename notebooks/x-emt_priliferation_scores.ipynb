# %%
from stfe.gene_utils import get_proliferation_score_cell_cycle, get_emt_score, get_markers_from_var_names
import scanpy as sc
import scprep

# %%
adata = sc.read_h5ad('../dmae_data/epithelial_Rbm10_OR18.h5ad')

# %%
proliferation_scores = get_proliferation_score_cell_cycle(adata)
emt_scores = get_emt_score(adata)
# Out:
# HN1 NOT FOUND!
# MLF1IP NOT FOUND!
# FAM64A NOT FOUND!
# WARNING: Some proliferation genes missing. Got 95/98.
# MLF1IP NOT FOUND!
# WARNING: Some S genes missing. Got 42/43.
# FAM64A NOT FOUND!
# HN1 NOT FOUND!
# WARNING: Some G2M genes missing. Got 52/54.
# C1orf116 NOT FOUND!
# WARNING: Some EMT genes missing. Got 70/71.

# %%
emt_scores
# Out:
# EPCRbm10_MDC_18_OR_GAACACTAGGATACTG-1   -0.013673
# EPCRbm10_MDC_18_OR_ATTCCTAAGGCTATCT-1    3.123295
# EPCRbm10_MDC_18_OR_CCGAACGTCATTCTTG-1    1.359021
# EPCRbm10_MDC_18_OR_GGATCTAAGCATTGAA-1    3.326585
# EPCRbm10_MDC_18_OR_ACTTTGTTCACGATCA-1    5.896457
#                                            ...
# EPCRbm10_MDC_1_MRDCTTTCGGAGGCCTAAG-1     3.593286
# EPCRbm10_MDC_1_MRDTACATTCAGTACTCGT-1     1.594017
# EPCRbm10_MDC_1_MRDGATCAGTTCATTTGTC-1     1.298969
# EPCRbm10_MDC_1_MRDTGGATCACAGGCGAAT-1     2.657949
# EPCRbm10_MDC_1_MRDCGGCAGTAGTATGGAT-1     1.712921
# Length: 5396, dtype: float64

# %%
proliferation_scores
# Out:
#                                       phase   S_score  G2M_score  \
# EPCRbm10_MDC_18_OR_GAACACTAGGATACTG-1    G1 -0.054770  -0.076271
# EPCRbm10_MDC_18_OR_ATTCCTAAGGCTATCT-1    G1 -0.024898  -0.094758
# EPCRbm10_MDC_18_OR_CCGAACGTCATTCTTG-1     S  0.015714  -0.038724
# EPCRbm10_MDC_18_OR_GGATCTAAGCATTGAA-1    G1 -0.006388  -0.050619
# EPCRbm10_MDC_18_OR_ACTTTGTTCACGATCA-1    G1 -0.029982  -0.073880
# ...                                     ...       ...        ...
# EPCRbm10_MDC_1_MRDCTTTCGGAGGCCTAAG-1     G1 -0.038242  -0.123551
# EPCRbm10_MDC_1_MRDTACATTCAGTACTCGT-1     G1 -0.030227  -0.099381
# EPCRbm10_MDC_1_MRDGATCAGTTCATTTGTC-1    G2M  0.004272   0.004454
# EPCRbm10_MDC_1_MRDTGGATCACAGGCGAAT-1     G1 -0.024028  -0.055395
# EPCRbm10_MDC_1_MRDCGGCAGTAGTATGGAT-1    G2M  0.000369   0.183700
#
#                                        proliferation_score
# EPCRbm10_MDC_18_OR_GAACACTAGGATACTG-1            -0.087843
# EPCRbm10_MDC_18_OR_ATTCCTAAGGCTATCT-1            -0.079607
# ...

# %%
scprep.plot.scatter2d(adata.obsm['X_phate_2d'], emt_scores, ticks=False, label_prefix='PHATE', title='EMT score')
# Out:
# /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/.conda_envs/mioflow/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# <Axes: title={'center': 'EMT score'}, xlabel='PHATE1', ylabel='PHATE2'>

# %%
for name in proliferation_scores.columns:
    scprep.plot.scatter2d(adata.obsm['X_phate_2d'], proliferation_scores[name], ticks=False, label_prefix='PHATE', title=name)
# Out:
# /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/.conda_envs/mioflow/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/.conda_envs/mioflow/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/.conda_envs/mioflow/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# /gpfs/gibbs/pi/krishnaswamy_smita/xingzhi/.conda_envs/mioflow/lib/python3.10/site-packages/scprep/plot/utils.py:104: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
