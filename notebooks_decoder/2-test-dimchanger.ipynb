# %%
import torch
import numpy as np
import sys
sys.path.append("../src")
from dimchanger import DimChanger
import matplotlib.pyplot as plt

# %%
dimchanger = DimChanger.load('../model')

# %%
X_pca = np.load('../data_main/X_pca.npy')
X_phate = np.load('../data_main/X_phate.npy')
X_phate_vis = np.load('../data_main/X_phate_vis.npy')

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], s=1)
# plt.scatter(X_phate[:, 0], X_phate[:, 1], s=1)
# plt.scatter(X_phate_vis[:, 0], X_phate_vis[:, 1], s=1)

# %%
dimchanger.phate_scaler.n_features_in_
# Out:
# 10

# %%
x_pca_rec = dimchanger.phate2pca(X_phate)
x_phate_vis = dimchanger.phate2vis(X_phate)

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], s=1)
plt.scatter(x_pca_rec[:, 0], x_pca_rec[:, 1], s=1)

# %%
plt.scatter(X_phate[:, 0], X_phate[:, 1], s=1)

# %%
plt.scatter(X_phate_vis[:, 0], X_phate_vis[:, 1], s=1)
plt.scatter(x_phate_vis[:, 0], x_phate_vis[:, 1], s=1)
plt.scatter(X_phate[:, 0], X_phate[:, 1], s=1)
